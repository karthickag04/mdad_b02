# %%
# %pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
# %pip install openpyxl
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests,openpyxl

# %%
try:
    22/0
except ZeroDivisionError as e:
    print("You can't divide by zero!")
    print(e)
# Out:
# You can't divide by zero!
# division by zero

# %%
link="https://catking.in/list-of-countries-capitals-currencies-of-the-world"

# %%
try:
    htmlpage_response=requests.get(link)
    soup=BeautifulSoup(htmlpage_response.text,'html.parser')
    print(soup)
except Exception as e:
    print(e)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <meta content="7fpAyW11zCNvmUCXB2ZZyOVOHdtAra87MESkS9lP" name="csrf-token"/>
# <meta content="Discover an updated list of countries with their capitals and currencies. Explore a comprehensive guide to world capitals, currencies, and more in 2025." name="description"/>
# <meta content="General Knowledge, IBPS Banking, countries with capitals, countries and currencies, capital cities, list of countries, world capitals and currencies, country currencies, country list with capitals" name="keywords"/>
# <meta content="List of all countries with their capitals and currencies" name="title"/>
# <meta content="3zWDOZRxOwxUdX1epanktOahJfEexYR1jw-4E5YMemE" name="google-site-verification">
# <title>List of all countries with their capitals and currencies</title>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import openpyxl

# %%
# The URL of the webpage
url = "https://catking.in/list-of-countries-capitals-currencies-of-the-world"

# Send a GET request to fetch the HTML content
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Find the table by the tag <table>
table = soup.find('table')

# %%
print(table)
# Out:
# <table border="1" data-end="3217" data-start="2250" style="width: 84%; height: 419.89px; border-collapse: collapse; background-color: #e4f9f7; border-color: #2dc26b;">
# <tbody data-end="3217" data-start="2340">
# <tr style="height: 39.3828px;">
# <td style="background-color: #a8f3c1; width: 27.6239%; text-align: center; height: 39.3828px; border-color: #2dc26b;"><span id="strong-10-country"><strong data-end="2263" data-start="2252">Country</strong></span></td>
# <td style="background-color: #a8f3c1; width: 28.059%; text-align: center; height: 39.3828px; border-color: #2dc26b;"><span id="strong-11-capital"><strong data-end="2277" data-start="2266">Capital</strong></span></td>
# <td style="background-color: #a8f3c1; width: 44.3723%; text-align: center; height: 39.3828px; border-color: #2dc26b;"><span id="strong-12-currency"><strong data-end="2292" data-start="2280">Currency</strong></span></td>
# </tr>
# <tr data-end="2392" data-start="2340" style="height: 22.3828px;">
# ...

# %%
# Extract the headers from the first row (the <tr> tag within <thead> or first <tr>)
headers = []
for th in table.find_all('th'):
    headers.append(th.text.strip())
print(headers)

# If the headers are within a <tr> inside <tbody>, use this:
if not headers:
    headers = [header.text.strip() for header in table.find_all('td')[:3]]  # Modify according to your needs
print(headers)
# # # Extract the rows
rows = []
for row in table.find_all('tr')[1:]:  # Skipping the header row
    td_list = row.find_all('td')
    # print(cols)
    # for eachitem in td_list:
    #     print(eachitem.text.strip())
    td_list = [eachitem.text.strip() for eachitem in td_list]
    # print (cols)
    rows.append(td_list)

print(rows)
# Out:
# []
# ['Country', 'Capital', 'Currency']
# [['Afghanistan', 'Kabul', 'Afghan Afghani (AFN)'], ['Albania', 'Tirana', 'Albanian Lek (ALL)'], ['Algeria', 'Algiers', 'Algerian Dinar (DZD)'], ['Argentina', 'Buenos Aires', 'Argentine Peso (ARS)'], ['Australia', 'Canberra', 'Australian Dollar (AUD)'], ['Brazil', 'Brasília', 'Brazilian Real (BRL)'], ['Canada', 'Ottawa', 'Canadian Dollar (CAD)'], ['China', 'Beijing', 'Chinese Yuan (CNY)'], ['France', 'Paris', 'Euro (EUR)'], ['Germany', 'Berlin', 'Euro (EUR)'], ['India', 'New Delhi', 'Indian Rupee (INR)'], ['Italy', 'Rome', 'Euro (EUR)'], ['Japan', 'Tokyo', 'Japanese Yen (JPY)'], ['Mexico', 'Mexico City', 'Mexican Peso (MXN)'], ['South Korea', 'Seoul', 'South Korean Won (KRW)'], ['United Kingdom', 'London', 'British Pound (GBP)'], ['United States', 'Washington D.C.', 'United States Dollar (USD)']]

# %%
# # Assuming headers are in the first row of the table
# headers = [header.text.strip() for header in table.find_all('tr')[0].find_all('td')]

# # print(headers)

# # Extract the rows starting from the second row onward
# rows = []
# for row in table.find_all('tr')[1:]:
#     cols = row.find_all('td')
#     cols = [ele.text.strip() for ele in cols]
#     rows.append(cols)

# %%
# Convert the data into a Pandas DataFrame
df = pd.DataFrame(rows, columns=headers)
df.head()
# Out:
#        Country       Capital                 Currency
# 0  Afghanistan         Kabul     Afghan Afghani (AFN)
# 1      Albania        Tirana       Albanian Lek (ALL)
# 2      Algeria       Algiers     Algerian Dinar (DZD)
# 3    Argentina  Buenos Aires     Argentine Peso (ARS)
# 4    Australia      Canberra  Australian Dollar (AUD)

# %%
# Display the DataFrame
print(df)

# Optionally, save the DataFrame to a CSV file
df.to_csv('countries_capitals_currencies.csv', index=False)
# Out:
#            Country          Capital                    Currency
# 0      Afghanistan            Kabul        Afghan Afghani (AFN)
# 1          Albania           Tirana          Albanian Lek (ALL)
# 2          Algeria          Algiers        Algerian Dinar (DZD)
# 3        Argentina     Buenos Aires        Argentine Peso (ARS)
# 4        Australia         Canberra     Australian Dollar (AUD)
# 5           Brazil         Brasília        Brazilian Real (BRL)
# 6           Canada           Ottawa       Canadian Dollar (CAD)
# 7            China          Beijing          Chinese Yuan (CNY)
# 8           France            Paris                  Euro (EUR)
# 9          Germany           Berlin                  Euro (EUR)
# 10           India        New Delhi          Indian Rupee (INR)
# 11           Italy             Rome                  Euro (EUR)
# 12           Japan            Tokyo          Japanese Yen (JPY)
# 13          Mexico      Mexico City          Mexican Peso (MXN)
# ...

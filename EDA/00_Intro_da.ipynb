# %% [markdown]
# ## Process of Datascience / Data Analysis

# %%
import os
from IPython.display import display, Image

# Path to your images folder
image_folder = 'images'

# List all image files in the images folder
image_files = [f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg', '.gif'))]

# Specify the filenames of the three images you want to display
specific_images = ['da_process.png', 'types_of_data.png', 'types_of_data_01.png','visualization.PNG','visualization_1.PNG']

# Display the specified images
for image_file in specific_images:
    image_path = os.path.join(image_folder, image_file)
    display(Image(filename=image_path))
